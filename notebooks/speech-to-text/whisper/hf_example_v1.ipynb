# %% [markdown]
# https://huggingface.co/openai/whisper-tiny.en

# %%
from transformers import WhisperProcessor, WhisperForConditionalGeneration
import torch

device = "cuda"

processor = WhisperProcessor.from_pretrained("openai/whisper-tiny.en")

model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-tiny.en", torch_dtype=torch.float16).to(device)

input_features = processor(sample["array"], sampling_rate=sample["sampling_rate"], return_tensors="pt").input_features.to(device).half()   # <<< força float16

with torch.inference_mode():
    predicted_ids = model.generate(input_features)

transcription = processor.batch_decode(predicted_ids, skip_special_tokens=True)

# %%
transcription
# Out:
# [' Mr. Quilter is the apostle of the middle classes, and we are glad to welcome his gospel.']
